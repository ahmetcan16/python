# %% [markdown]
# # SEABORN
#
# https://seaborn.pydata.org/

# %% [markdown]
# ![image_720.png](attachment:image_720.png)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl 
# versiyon kontrol, default değerlere dönme vs için

import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline 
#bunu yazmassak bütün göreselleri bir araya toplar
# %matplotlib notebook : interaktif görüntü almak için

import warnings;
warnings.filterwarnings("ignore")

# %%
tips = sns.load_dataset("tips")

# %%
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 120       11.69  2.31    Male     No  Thur   Lunch     2
# 53         9.94  1.56    Male     No   Sun  Dinner     2
# 154       19.77  2.00    Male     No   Sun  Dinner     4
# 34        17.78  3.27    Male     No   Sat  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# # sns.scatterplot()
#
# Dağılım grafikleri, farklı özelliklerin birbiriyle olan ilişkisini(korelasyon) görüntülemek için kullanılır

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip")

plt.show()

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex")
#hue ile gruplama yaptık

plt.show()

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = tips["total_bill"], y = tips.tip, hue = tips.sex)

plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = tips["total_bill"], y = tips.tip, hue = tips.smoker, palette = ("black", "red"))
#palette ile noktaların renklerini ayarladık
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = tips["total_bill"], y = tips.tip, hue = tips.day)
#palette ile noktaların renklerini ayarladık
plt.show()

# %% [markdown]
# # sns.regplot()
#
# regresyon çizgisini koydu

# %%
sns.regplot(data = tips, x = "total_bill", y = "tip")
plt.show()

# %% [markdown]
# ## Style

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex")
plt.show()
# hue : renkledirerek gruplar
# style : işaretle gruplar

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day")
plt.show()
# hue : renkledirerek gruplar
# style : işaretle gruplar

# %%
# %matplotlib notebook

plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "sex")
plt.show()

# hue : renkledirerek gruplar
# style : işaretle gruplar
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", ax = ax[0])
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker", ax = ax[1])

plt.show()

# %% [markdown]
# ## palette (color)
#
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", palette = "plasma")

plt.show()

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", palette = "viridis")

plt.show()

# %% [markdown]
# ## alpha (yoğunluk)

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", alpha = 0.5)

plt.show()

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", 
                hue = "day", style = "sex", alpha = 0.7, palette = "plasma")

plt.show()

# %% [markdown]
# ## s parameter

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", 
                hue = "day", style = "sex", alpha = 0.7, s = 100)
# s ile noktaların boyutlarıyla oynayabiliriz
plt.show()

# %% [markdown]
# ## size parameter

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", 
                hue = "smoker", size = "sex")
# size ile gruplamayı noktaların büyüklüğüyle belirtiriz
plt.show()

# %%
# the relationship between ``x`` and ``y`` can be shown for different subsets
#of the data using the ``hue``, ``size``, and ``style`` parameters.

# %% [markdown]
# # sns.displot()
#
# her bara bins denir

# %%
sns.displot(data = tips, x = "total_bill")

plt.show()

# %%
sns.displot(data = tips, x = "total_bill", kind = "kde")
#kind : {"hist", "kde", "ecdf"}

plt.show()

# %%
sns.displot(data = tips, x = "total_bill", kde = True)

plt.show()

# %%
sns.displot(data = tips, x = "total_bill", bins = 100, kde = True)

plt.show()

# %%
sns.displot(data = tips, x = "tip", kde = True, bins = 50)

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", s = 300, hue = "sex", ax = ax[0])
sns.histplot(data = tips, x = "total_bill", ax = ax[1], kde =True)

plt.show()

# %% [markdown]
# # sns.FacetGrid()

# %% [raw]
# Bu sınıf, bir veri kümesini, veri kümesindeki değişkenlerin seviyelerine karşılık gelen satır ve sütunlardan oluşan bir ızgarada dizilmiş birden çok eksene eşler. Ürettiği grafikler genellikle “lattice”, “trellis”, or “small-multiple” şeklinde adlandırılır.
#
# Ayrıca, farklı veri alt kümelerini farklı renklerde çizen hue parametresiyle üçüncü bir değişkenin seviyelerini de temsil edebilir. Bu, üçüncü bir boyuttaki öğeleri çözümlemek için renk kullanır, ancak yalnızca alt kümeleri üst üste çizer ve hue parametresini, hue kabul eden eksen düzeyi işlevlerinin yapacağı şekilde belirli görselleştirme için uyarlamaz.
#
# Temel iş akışı, FacetGrid nesnesini veri kümesi ve ızgarayı yapılandırmak için kullanılan değişkenlerle başlatmaktır. Ardından FacetGrid.map() veya FacetGrid.map_dataframe() çağrılarak her alt kümeye bir veya daha fazla çizim işlevi uygulanabilir. Son olarak, eksen etiketlerini değiştirmek, farklı tikler kullanmak veya bir gösterge eklemek gibi şeyler yapmak için çizim diğer yöntemlerle değiştirilebilir. Daha fazla bilgi için aşağıdaki ayrıntılı kod örneklerine bakın.

# %%
g = sns.FacetGrid(data = tips, col = "sex", hue = "smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha = 0.5)
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(data = tips, col = "sex", row = "smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha = 0.5)
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(data = tips, col = "sex", hue = "smoker")
g.map(sns.kdeplot, "total_bill", "tip", alpha = 0.5, shade = True)
g.add_legend()

plt.show()

# %%
sns.kdeplot(data = tips[tips.sex == "Male"], x = "total_bill", y = "tip", hue = "smoker", shade = True)

plt.show()

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist")
sns.displot(data = tips, x = "total_bill", kind = "kde");

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist", kde = True, aspect = 1)

plt.show()

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist", kde = True, aspect = 5)

plt.show()

# %% [markdown]
# # sns.hisplot()

# %%
plt.figure(figsize = (10, 5))

sns.histplot(data = tips, x = "total_bill", bins = 50, kde = True)
plt.show()

# %% [markdown]
# ## Doppler effect

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.rugplot(data = tips, x = "total_bill", ax = ax[0])
sns.histplot(data = tips, x = "total_bill", ax = ax[1], kde = True)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.rugplot(data = tips, x = "total_bill", ax = ax[0], height = 0.5)
sns.kdeplot(data = tips, x = "total_bill", ax = ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.rugplot(data=tips, x="total_bill", height=0.1, ax=ax[0])
sns.histplot(data=tips, x="total_bill", ax=ax[1])
plt.show()

# %%
sns.set(style = "dark")
sns.histplot(data = tips, x = "tip", kde = True)
plt.show()

# %% [markdown]
# # sns.kdeplot()
#
# kernel density estimation

# %%
penguins = sns.load_dataset("penguins")
penguins.sample(10)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 203  Chinstrap   Dream            51.4           19.0              201.0
# 245     Gentoo  Biscoe            46.1           15.1              215.0
# 56      Adelie  Biscoe            39.0           17.5              186.0
# 30      Adelie   Dream            39.5           16.7              178.0
# 47      Adelie   Dream            37.5           18.9              179.0
# 304     Gentoo  Biscoe            44.9           13.8              212.0
# 232     Gentoo  Biscoe            45.5           13.7              214.0
# 196  Chinstrap   Dream            50.9           17.9              196.0
# 248     Gentoo  Biscoe            48.2           14.3              210.0
# 312     Gentoo  Biscoe            45.5           14.5              212.0
#
#      body_mass_g     sex
# 203       3950.0    Male
# 245       5100.0    Male
# 56        3550.0  Female
# 30        3250.0  Female
# 47        2975.0     NaN
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins.sex.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
sns.kdeplot(data = penguins, x = "body_mass_g");

# %%
sns.kdeplot(data = penguins, x = "body_mass_g", hue = "sex");

# %%
sns.kdeplot(data = penguins, x = "body_mass_g", hue = "species", shade = True);

# %%
sns.kdeplot(data = penguins, x = "bill_length_mm", hue = "sex", shade = True);

# %% [markdown]
# ## 2D kdeplot
#
# izohips benzeri

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip")

plt.show()

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red")

plt.show()

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True)

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True, ax = ax[1])
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "red",  ax = ax[0])

plt.show()

# %%
sns.displot(data = penguins,
           x = "body_mass_g",
           bins = 20,
           rug = True,
           kde = True);

# %%
fig, ax = plt.subplots(2, 2, figsize = (10, 5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "purple", shade = True, ax = ax[0][0])
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "red", ax = ax[0][1])
sns.histplot(data = tips, x = "total_bill",  color = "orange", ax = ax[1][0])
sns.rugplot(data = tips, x = "total_bill", height = 0.5, color = "blue", ax = ax[1][1])

plt.show()

# %%
cars = sns.load_dataset("mpg")
cars.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 190  14.5          8         351.0       152.0    4215          12.8
# 290  15.5          8         351.0       142.0    4054          14.3
# 26   10.0          8         307.0       200.0    4376          15.0
# 36   19.0          6         250.0        88.0    3302          15.5
# 372  27.0          4         151.0        90.0    2735          18.0
# 154  15.0          6         250.0        72.0    3432          21.0
# 243  21.5          3          80.0       110.0    2720          13.5
# 185  26.0          4          98.0        79.0    2255          17.7
# 251  20.2          8         302.0       139.0    3570          12.8
# 257  19.4          6         232.0        90.0    3210          17.2
#
#      model_year origin                      name
# 190          76    usa          ford gran torino
# 290          79    usa  ford country squire (sw)
# 26           70    usa                 chevy c20
# ...

# %%
sns.displot(data = cars, x = "weight", hue = "origin")

# %%
sns.displot(data = cars[cars.cylinders.isin([4, 6, 8])], x = "weight",
           col = "origin",
           row = "cylinders",
           hue = "cylinders");

# %% [markdown]
# # Categorical Plot

# %% [markdown]
# ## sns.countplot()

# %%
sns.countplot(data = tips, x = "day");

# %% [raw]
# fig, ax = plt.subplots()
# ax = sns.countplot(tips["day"])
# for p in ax.patches:
#     ax.annotate((p.get_height()), (p.get_x()+0.32, p.get_height()+ 0.3));

# %%
ax = sns.countplot(data = tips, x = "day")
ax.bar_label(ax.containers[0])
plt.show()

# %%
tips = sns.load_dataset("tips")
ax = sns.countplot(data = tips, x = "day", hue="sex")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
fig, ax_tip = plt.subplots(figsize = (10,5))

ax_tip = sns.countplot(data = tips, x = "day",  hue = "sex");

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height() / tips.day.count()), (p.get_x()+0.15, p.get_height()+1));

# %%
fig, ax = plt.subplots(figsize = (12, 6))
ax = sns.countplot(x = "day",  data = tips, hue = "sex");
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.15, p.get_height()+0.7))
    ax.text(p.get_x()+0.07, p.get_height()-4, "%"+str(round(p.get_height()/tips.day.count()*100, 2)))
plt.legend(loc = "upper left");

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(data = mpg, x = "cylinders");

# %%
sns.countplot(x = mpg.model_year);

# %%
plt.figure(figsize = (10, 5))

sns.set(style = "whitegrid")

sns.countplot(data = mpg, x = "model_year", hue = "origin")

plt.legend(loc = "upper right");

# %% [markdown]
# ![image_720.png](attachment:image_720.png)

# %% [markdown]
# ## sns.barplot()

# %%
sns.barplot(data = tips, x = "sex", y = "tip")
# default olarak estimator : mean'dir

# %%
tips.groupby("sex").tip.mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
sns.barplot(data = tips, x = "sex", y = "tip", estimator = "sum");

# %%
sns.barplot(data = tips, x = "sex", y = "tip", ci = "sd");

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x = "day", data = tips)
for p in ax.patches:
    ax.annotate("("+str(p.get_height())+")" +
                "%" + str(round((p.get_height())/ tips.day.count(), 2)*100), (p.get_x() + 0.07, p.get_height()-10));

# %% [markdown]
# ## barplot vs countplot

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 6))

sns.barplot(x = "day", y = "total_bill", data = tips, ax = ax[0])
sns.countplot(x = "day",  data = tips, ax = ax[1]);

# %% [markdown]
# ## sns.boxplot()

# %%
sns.boxplot(data = tips, x = "day", y = "tip");

# %% [markdown]
# ![image_720.png](attachment:image_720.png)

# %%
sns.boxplot(data = tips, x = "day", y = "tip", hue = "sex");

# %%
plt.subplots(figsize = (10, 5))

sns.boxplot(data = tips, x = "tip", y = "day", hue = "sex");

# %% [markdown]
# ## sns.violinplot()

# %%
plt.subplots(figsize = (10, 5))

sns.violinplot(data = tips, x = "day", y = "tip");

# %%
plt.subplots(figsize = (10,5))
sns.violinplot(y = "tip", x = "day", data = tips, hue = "sex");

# %%
plt.subplots(figsize = (10,5))
sns.violinplot(y = "tip", x = "day", data = tips, hue = "sex", split = True);

# %% [markdown]
# ## sns.swarmplot()

# %%
plt.figure(figsize = (10,5))

sns.swarmplot(y = "total_bill", data = tips, size = 10, x = "smoker", hue = "sex");

# %% [markdown]
# # Comparison plots

# %% [markdown]
# ## sns.jointplot()

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "scatter", alpha = 0.7);

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "hex", alpha = 0.7);

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "kde", alpha = 0.7);
